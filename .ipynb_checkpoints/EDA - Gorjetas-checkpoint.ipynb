# %% [markdown]
# # Importando base de dados

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/tips.csv')

# %%
dados.head(10)
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4
# 5       25.29  4.71      No  Sun  Dinner     4
# 6        8.77  2.00      No  Sun  Dinner     2
# 7       26.88  3.12      No  Sun  Dinner     4
# 8       15.04  1.96      No  Sun  Dinner     2
# 9       14.78  3.23      No  Sun  Dinner     2

# %% [markdown]
# # Traduzindo o conteúdo

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill': 'valor_da_conta',
    'tip': 'gorjeta',
    'dessert': 'sobremesa',
    'day': 'dia_da_semana',
    'time': 'hora_do_dia',
    'size': 'total_de_pessoas'
}

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas.head(10)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
# 1           10.34     1.66        No           Sun      Dinner
# 2           21.01     3.50        No           Sun      Dinner
# 3           23.68     3.31        No           Sun      Dinner
# 4           24.59     3.61        No           Sun      Dinner
# 5           25.29     4.71        No           Sun      Dinner
# 6            8.77     2.00        No           Sun      Dinner
# 7           26.88     3.12        No           Sun      Dinner
# 8           15.04     1.96        No           Sun      Dinner
# 9           14.78     3.23        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4
# 5                 4
# 6                 2
# 7                 4
# 8                 2
# 9                 2

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No': 'Não',
    'Yes': 'Sim'
}

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(10)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
# 1           10.34     1.66       Não           Sun      Dinner
# 2           21.01     3.50       Não           Sun      Dinner
# 3           23.68     3.31       Não           Sun      Dinner
# 4           24.59     3.61       Não           Sun      Dinner
# 5           25.29     4.71       Não           Sun      Dinner
# 6            8.77     2.00       Não           Sun      Dinner
# 7           26.88     3.12       Não           Sun      Dinner
# 8           15.04     1.96       Não           Sun      Dinner
# 9           14.78     3.23       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4
# 5                 4
# 6                 2
# 7                 4
# 8                 2
# 9                 2

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun': 'Domingo',
    'Sat': 'Sabado',
    'Thur': 'Quinta',
    'Fri': 'Sexta'
}

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sabado', 'Quinta', 'Sexta'], dtype=object)

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner': 'Jantar',
    'Lunch': 'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %% [markdown]
# # Importando o Seaborn

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.11.2
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@gmail.com
# License: BSD (3-clause)
# Location: c:\python310\lib\site-packages
# Requires: matplotlib, numpy, pandas, scipy
# Required-by:

# %% [markdown]
# # Análise 1 - Valor da conta e gorjeta

# %%
gorjetas.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
valor_gorjeta = sns.scatterplot(x = 'valor_da_conta', y = 'gorjeta', data = gorjetas)

# %% [markdown]
# #### Visualmente o valor da gorjeta aumenta conforme aumenta o valor da conta

# %%
print('A base de dados contém {} registros\n'.format(gorjetas.shape[0]))
print('Registros não nulos:')
gorjetas.count()
# Out:
# A base de dados contém 3416 registros
#
# Registros não nulos:
# valor_da_conta      3416
# gorjeta             3416
# sobremesa           3416
# dia_da_semana       3416
# hora_do_dia         3416
# total_de_pessoas    3416
# dtype: int64

# %% [markdown]
# ## Criando o campo porcentagem

# %%
gorjetas.head(10)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
# 5           25.29     4.71       Não       Domingo      Jantar
# 6            8.77     2.00       Não       Domingo      Jantar
# 7           26.88     3.12       Não       Domingo      Jantar
# 8           15.04     1.96       Não       Domingo      Jantar
# 9           14.78     3.23       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4
# 5                 4
# 6                 2
# 7                 4
# 8                 2
# 9                 2

# %%
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta']

# %%
gorjetas.head(10)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
# 5           25.29     4.71       Não       Domingo      Jantar
# 6            8.77     2.00       Não       Domingo      Jantar
# 7           26.88     3.12       Não       Domingo      Jantar
# 8           15.04     1.96       Não       Domingo      Jantar
# 9           14.78     3.23       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808
# 5                 4     0.186240
# 6                 2     0.228050
# 7                 4     0.116071
# 8                 2     0.130319
# 9                 2     0.218539

# %%
gorjetas.pocentagem = gorjetas.porcentagem.round(2)
# Out:
# C:\Users\evers\AppData\Local\Temp/ipykernel_1352/1524116159.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   gorjetas.pocentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas.sample(10)
# Out:
#       valor_da_conta   gorjeta sobremesa dia_da_semana hora_do_dia  \
# 2432       13.012173  0.908320       Sim        Sabado      Jantar
# 2308       39.372840  3.107241       Não       Domingo      Jantar
# 2254       11.285316  1.596225       Sim        Sabado      Jantar
# 1999       29.449134  4.671947       Não       Domingo      Jantar
# 1640       17.631710  2.092861       Sim       Domingo      Jantar
# 1698       15.026122  3.242582       Sim        Sabado      Jantar
# 117        10.650000  1.500000       Não        Quinta      Almoço
# 124        12.480000  2.520000       Não        Quinta      Almoço
# 2744       20.518013  2.470275       Sim        Sabado      Jantar
# 101        15.380000  3.000000       Sim         Sexta      Jantar
#
#       total_de_pessoas  porcentagem
# 2432                 2     0.069805
# 2308                 3     0.078918
# 2254                 2     0.141443
# 1999                 4     0.158645
# 1640                 2     0.118699
# 1698                 2     0.215796
# 117                  2     0.140845
# 124                  2     0.201923
# 2744                 2     0.120395
# 101                  2     0.195059

# %%
porcentagem_conta = sns.scatterplot(x = 'valor_da_conta', y = 'porcentagem', data = gorjetas)

# %% [markdown]
# #### *Visualmente o valor da conta não é proporcional ao valor da gorjeta*

# %%
porcentagem_conta_linha = sns.relplot(x = 'valor_da_conta', y = 'porcentagem', kind='line', data = gorjetas)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', data = gorjetas)

# %% [markdown]
# # Algumas formatações de gráficos

# %%
porcentagem_conta.get_figure() #Ver o gráfico novamente

# %%
porcentagem_conta.figure.suptitle('Valor da conta X Porcentagem') #Definindo um subtitulo
# Out:
# Text(0.5, 0.98, 'Valor da conta X Porcentagem')

# %%
porcentagem_conta.set_title('Análise do valor da conta em função da porcentagem de gorjetas') #Definindo um título
# Out:
# Text(0.5, 1.0, 'Análise do valor da conta em função da porcentagem de gorjetas')

# %%
porcentagem_conta.set(xlabel = 'Valor da conta', ylabel = 'Porcentagem de gorjetas')
# Out:
# [Text(0.5, 18.106250000000003, 'Valor da conta'),
#  Text(17.200000000000003, 0.5, 'Porcentagem de gorjetas')]

# %%
porcentagem_conta.get_figure() #Visualizar gráfico novamente após as alterações

# %%
porcentagem_conta.get_figure().savefig('imagem.png') #Salvando uma imagem do gráfico

# %% [markdown]
# # Análise 2 - Sobremesa

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta      gorjeta  total_de_pessoas  porcentagem
# count     1302.000000  1302.000000       1302.000000  1302.000000
# mean        20.800076     2.710137          2.408602     0.153495
# std          9.901358     1.162280          0.806690     0.089080
# min          2.799644     0.766203          1.000000     0.021449
# 25%         13.495501     1.911661          2.000000     0.092670
# 50%         17.917059     2.434354          2.000000     0.146878
# 75%         26.807493     3.326298          3.000000     0.189035
# max         55.804318    10.000000          5.000000     0.813498

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta      gorjeta  total_de_pessoas  porcentagem
# count     2114.000000  2114.000000       2114.000000  2114.000000
# mean        19.223436     2.711837          2.668874     0.150043
# std          8.316030     1.024271          1.014848     0.044202
# min          6.533329     0.910509          1.000000     0.041987
# 25%         13.281977     1.931135          2.000000     0.120642
# 50%         17.736923     2.608222          2.000000     0.145750
# 75%         22.749482     3.284578          3.000000     0.177951
# max         53.091371     9.000000          6.000000     0.334780

# %%
sns.catplot(x = 'sobremesa', y = 'gorjeta', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'sobremesa', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'sobremesa', col = 'sobremesa',data = gorjetas)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'gorjeta', col = 'sobremesa', hue = 'sobremesa', data = gorjetas)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', col = 'sobremesa', hue = 'sobremesa', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'sobremesa', col = 'sobremesa', kind = 'line', data = gorjetas)

# %% [markdown]
# #### *Visualmente existe uma diferença no valor da gorjetas dos que pediram sobremesa para aqueles que não pediram*

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
#
# **A distribuição da taxa da gorjeta é a mesma nos dois grupos**
#
# **H<sup>alt</sup>**
#
# **A distribuição da taxa da gorjeta não é a mesma nos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem
sobremesa
# Out:
# 56      0.078927
# 58      0.156584
# 60      0.158206
# 61      0.144823
# 62      0.179673
#           ...
# 3406    0.175754
# 3408    0.088221
# 3409    0.025419
# 3412    0.062825
# 3413    0.080471
# Name: porcentagem, Length: 1302, dtype: float64

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem
sem_sobremesa
# Out:
# 0       0.059447
# 1       0.160542
# 2       0.166587
# 3       0.139780
# 4       0.146808
#           ...
# 3407    0.118701
# 3410    0.091971
# 3411    0.179600
# 3414    0.090632
# 3415    0.155543
# Name: porcentagem, Length: 2114, dtype: float64

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.036051425250648333

# %% [markdown]
# **H<sup>alt</sup>**
#
# **A distribuição da taxa da gorjeta não é a mesma nos dois grupos**

# %% [markdown]
# O p-value representa a probabilidade da amostra ter acontecido dentro da população. Se a chance é pequena, geralmente p-value < 0,05, representa que um evento muito raro aconteceu, então optamos por descartar a hipótese nula, e dizer que ela pode não ser verdade. No nosso caso podemos desconsiderar a hipótese alternativa pois o p-value foi menor que 0,5

# %% [markdown]
# # Análise 3 - Dia da semana

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sabado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x = 'dia_da_semana', y = 'valor_da_conta', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'dia_da_semana', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjetas)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjetas)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()

# %%
print('A média geral das gorjetas é de {}'.format(media_geral_gorjetas))
# Out:
# A média geral das gorjetas é de 2.711189214091612

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.439133  2.902079     0.154985
# Quinta              17.724088  2.556177     0.154215
# Sabado              20.480249  2.690114     0.143576
# Sexta               17.215616  2.549960     0.163171

# %%
print('Frequência dos dias:')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias:
# Sabado     1218
# Domingo    1064
# Quinta      868
# Sexta       266
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
#
# **A distribuição do valor da conta é igual no sábado e no domingo**
#
# **H<sup>alt</sup>**
#
# **A distribuição do valor da conta não é igual no sábado e no domingo**

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sabado'").valor_da_conta

# %%
r2 = ranksums(valor_conta_domingo, valor_conta_sabado)
print('O valor do p-value é {}'.format(r2.pvalue))
# Out:
# O valor do p-value é 0.0004435935681441821

# %% [markdown]
# **H<sup>alt</sup>**
#
# **A distribuição do valor da conta não é igual no sábado e no domingo**

# %% [markdown]
# # Análise 4 - Hora do dia

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x = 'hora_do_dia', y = 'valor_da_conta', data = gorjetas)

# %%
sns.catplot(x = 'hora_do_dia', y = 'valor_da_conta', kind='swarm', data = gorjetas)
# Out:
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x = 'hora_do_dia', y = 'valor_da_conta', data = gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x = 'hora_do_dia', y = 'valor_da_conta', data = gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.histplot(almoco, kde = True)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Count'>

# %%
sns.histplot(almoco, kde = False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Count'>

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").valor_da_conta

# %%
sns.histplot(jantar, kde = True)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Count'>

# %%
sns.histplot(jantar)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Count'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.213913  2.534495     0.157784
# Jantar            20.832954  2.779458     0.148876

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
#
# **A distribuição do valor da conta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
#
# **A distribuição do valor da conta não é igual no jantar e no almoço**

# %%
r3 = ranksums(jantar, almoco)

# %%
print('O valor do p-value é de {}'.format(r3.pvalue))
# Out:
# O valor do p-value é de 5.169201062207143e-34

# %% [markdown]
# **H<sup>alt</sup>**
#
# **A distribuição do valor da conta não é igual no jantar e no almoço**

# %% [markdown]
# ## Teste de hipótese 2

# %% [markdown]
# **H<sup>null</sup>**
#
# **A distribuição da taxa da gorjeta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
#
# **A distribuição da taxa da gorjeta não é igual no jantar e no almoço**

# %%
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
r4 = ranksums(porcentagem_almoco, porcentagem_jantar)

# %%
print('O valor do p-value é de {}'.format(r4.pvalue))
# Out:
# O valor do p-value é de 9.480580720296862e-12

# %% [markdown]
# **H<sup>alt</sup>**
#
# **A distribuição da taxa da gorjeta não é igual no jantar e no almoço**
